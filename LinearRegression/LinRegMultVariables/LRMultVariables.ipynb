# %%
from google.colab import drive

drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %% [markdown]
# 1. Abrindo arquivo txt e gravando as variaveis para geração de grafico

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
X1=[]
X2=[]
Y=[]

for linha in open("/content/drive/My Drive/Colab Notebooks/MachineLearning/ex1data2.txt"):
  x1, x2, y = linha.split(',') # Separa linhas por ","
  X1.append(float(x1))
  X2.append(float(x2))
  Y.append(float(y))

X1 = np.array(X1)
X2 = np.array(X2)
Y = np.array(Y)

# %% [markdown]
# 2. Plotando gráfico dos dados de treino

# %%
plt.scatter(X1, Y, marker="*", color='red')
plt.xlabel('Sqr feet', color='w')
plt.ylabel('Price of houses', color='w')
plt.show()

# %%
a = X2
unique, counts = np.unique(a, return_counts=True)
print(unique, unique.shape, type(unique),"\n",counts, counts.shape, type(counts))
# Out:
# [1. 2. 3. 4. 5.] (5,) <class 'numpy.ndarray'>
#  [ 1  6 25 14  1] (5,) <class 'numpy.ndarray'>

# %% [markdown]
# 3. Grafico de qtd de casas pela qtd de quartos

# %%
plt.bar(unique, counts)
plt.show()

# %% [markdown]
# ## Regressao Linear Multiplas Variaveis com Biblioteca Sklearn

# %%
from sklearn import linear_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/MachineLearning/ex1data2B.txt', sep=",",skiprows=[0], names=["sqrfeet","bedroom","price"])

# %%
df.head()
# Out:
#    sqrfeet  bedroom   price
# 0     2104        3  399900
# 1     1600        3  329900
# 2     2400        3  369000
# 3     1416        2  232000
# 4     3000        4  539900

# %%
reg = linear_model.LinearRegression()
reg.fit(df[["sqrfeet","bedroom"]], df.price)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Parametros (m1, m2, m...)
reg.coef_
# Out:
# array([  139.21067402, -8738.01911233])

# %%
# Parametro b
reg.intercept_
# Out:
# 89597.90954279754

# %%
# Previsao de preço para um casa de 2000 sqr feet e 4 badrooms
reg.predict([[2000,4]])
# Out:
# array([333067.18112874])

# %%
# Teste
139.21067402*2000 + (-8738.01911233)*4 + 89597.90954279754
# Out:
# 333067.18113347754
